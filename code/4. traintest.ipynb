# %%
import os
import gc
import time
import pickle
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
np.random.seed(0)

import mxnet as mx
from gluonts.evaluation import Evaluator
from gluonts.evaluation.backtest import make_evaluation_predictions
mx.random.seed(0)

from model import *
from utils import *

import warnings

warnings.filterwarnings("ignore", message="WARNING:gluonts.model.forecast:The mean prediction is not stored in the forecast data; the median is being returned instead. This behaviour may change in the future.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 15
#      13 from gluonts.evaluation import Evaluator
#      14 from gluonts.evaluation.backtest import make_evaluation_predictions
# ---> 15 mx.random.seed(0)
#      17 from model import *
#      18 from utils import *
#
# AttributeError: module 'mxnet' has no attribute 'random'

# %%
def train_models(epochs, learning_rate):    
    # save directory
    save_dir = f'../result/learning_rate_{learning_rate}-patience_15'
    os.makedirs(save_dir, exist_ok=True)
    
    for level_idx in range(1, 13):
        # level directory
        level_dir = os.path.join(save_dir, f'level_{level_idx}')
        os.makedirs(level_dir, exist_ok=True)

        highlight_print(f"\n========== Level {level_idx} ==========")
        print(f"Loading dataset...", end=' ')
        dataset_start = time.time()
        with open(os.path.join('../dataset', f'dataset_level_{level_idx}.pkl'), 'rb') as f:
            dataset = pickle.load(f)
        print(f"{(time.time() - dataset_start)/60:.1f} minutes")

        print("Normalizing dataset...", end=' ')
        normalize_start = time.time()
        norm_train_dataset, norm_test_dataset, normalizer = normalize_dataset(
            dataset['train'], 
            dataset['test'],
        )
        with open(os.path.join(level_dir, 'normalizer.pkl'), 'wb') as f:
            pickle.dump(normalizer, f)
        print(f"{(time.time() - normalize_start)/60:.1f} minutes")

        estimators = create_estimators(
            level_idx=level_idx, 
            train_dataset=norm_train_dataset
        )
        for estimator_name, estimator in estimators.items():
            # estimator directory
            estimator_dir = os.path.join(level_dir, estimator_name)
            os.makedirs(estimator_dir, exist_ok=True)

            estimator_start = time.time()

            highlight_print(f"\n---------- {estimator_name} ----------")
            print("Start training...")
            train_start = time.time()
            estimator.trainer = EarlyStoppingTrainer(
                epochs=epochs,
                learning_rate=learning_rate,
                num_batches_per_epoch=get_optimal_num_batches(mx.context.num_gpus()),
                patience=15,
            )
            predictor = estimator.train(
                training_data=norm_train_dataset,
                validation_data=norm_test_dataset
            )
            predictor.serialize(Path(f"{level_dir}/{estimator_name}"))
            highlight_print(f"End training... {(time.time() - train_start)/60:.1f} minutes", color='green')

            print("Start predicting...")
            pred_start = time.time()
            train_forecasts_it, train_labels_it = make_evaluation_predictions(
                dataset=norm_train_dataset,
                predictor=predictor,
            )
            train_forecasts = list(train_forecasts_it)
            train_labels = list(train_labels_it)

            test_forecasts_it, test_labels_it = make_evaluation_predictions(
                dataset=norm_test_dataset,
                predictor=predictor,
            )
            test_forecasts = list(test_forecasts_it)
            test_labels = list(test_labels_it)
            highlight_print(f"End predicting... {(time.time() - pred_start)/60:.1f} minutes", color='green')

            print("Start saving...")
            pred_save_start = time.time()
            for i in range(len(train_forecasts)):
                train_forecasts[i] = normalizer.inverse_transform_forecast(train_forecasts[i])
            for i in range(len(test_forecasts)):
                test_forecasts[i] = normalizer.inverse_transform_forecast(test_forecasts[i])
            for i in range(len(train_labels)):
                train_labels[i] = normalizer.inverse_transform_labels(train_labels[i])
            for i in range(len(test_labels)):
                test_labels[i] = normalizer.inverse_transform_labels(test_labels[i])
            with open(f"{level_dir}/{estimator_name}/train_labels.pkl", "wb") as f:
                pickle.dump(train_labels, f)
            with open(f"{level_dir}/{estimator_name}/train_forecasts.pkl", "wb") as f:
                pickle.dump(train_forecasts, f)
            with open(f"{level_dir}/{estimator_name}/test_labels.pkl", "wb") as f:
                pickle.dump(test_labels, f)
            with open(f"{level_dir}/{estimator_name}/test_forecasts.pkl", "wb") as f:
                pickle.dump(test_forecasts, f)
            highlight_print(f"End saving... {(time.time() - pred_save_start)/60:.1f} minutes", color='green')

            print("Start plotting...")
            plot_start = time.time()
            for i in range(len(test_forecasts)):
                plt.figure(figsize=(12, 6))
                plt.plot(test_labels[i][-100:].to_timestamp(), label="Actual")
                plt.plot(pd.Series(test_forecasts[i].quantile(0.5), index=test_forecasts[i].start_date.to_timestamp() + pd.to_timedelta(range(len(test_forecasts[0].quantile(0.5))), unit='D')), label="Forecast")
                plt.title(f'{test_forecasts[i].item_id}')
                plt.xlabel('Date')
                plt.ylabel('Sales')
                plt.legend(loc="upper right")
                plt.savefig(os.path.join(estimator_dir, f'series_{i + 1}.png'))
                plt.close()
            highlight_print(f"End plotting... {(time.time() - plot_start)/60:.1f} minutes", color='green')
                
            print("Start evaluating...")
            eval_start = time.time()
            evaluator = Evaluator(quantiles=(0.5,), ignore_invalid_values=True)
            train_metrics_all_id, train_metrics_per_id = evaluator(train_labels, train_forecasts)
            test_metrics_all_id, test_metrics_per_id = evaluator(test_labels, test_forecasts)
            highlight_print(f"End evaluating... {(time.time() - eval_start)/60:.1f} minutes", color='green')

            print("Start saving...")
            eval_save_start = time.time()
            with open(f"{level_dir}/{estimator_name}/train_metrics_all_id.pkl", "wb") as f:
                pickle.dump(train_metrics_all_id, f)
            with open(f"{level_dir}/{estimator_name}/train_metrics_per_id.pkl", "wb") as f:
                pickle.dump(train_metrics_per_id, f)
            with open(f"{level_dir}/{estimator_name}/test_metrics_all_id.pkl", "wb") as f:
                pickle.dump(test_metrics_all_id, f)
            with open(f"{level_dir}/{estimator_name}/test_metrics_per_id.pkl", "wb") as f:
                pickle.dump(test_metrics_per_id, f)
            highlight_print(f"End saving... {(time.time() - eval_save_start)/60:.1f} minutes", color='green')

            highlight_print(f"\nTotal time: {(time.time() - estimator_start)/60:.1f} minutes", color='red')

            # rename estimator directory
            os.rename(estimator_dir, f"{estimator_dir}_{test_metrics_all_id['MASE']:.2f}")

            # reduce memory
            del estimator, predictor, train_forecasts, train_labels, test_forecasts, test_labels
            gc.collect()

train_models(epochs=500, learning_rate=1e-3)
# Out:
# ========== Level 12 ==========
# Loading dataset... 0.2 minutes
# Normalizing dataset...
#   0%|          | 0/95 [00:00<?, ?it/s]
# 7.1 minutes
#
# ---------- DeepAR ----------
# Start training...
# 100%|██████████| 95/95 [00:10<00:00,  9.08it/s, epoch=1/500, avg_epoch_loss=-5.9]
# 953it [00:51, 18.36it/s, epoch=1/500, validation_avg_epoch_loss=-5.56]
# 100%|██████████| 95/95 [00:09<00:00, 10.36it/s, epoch=2/500, avg_epoch_loss=-6.63]
# 953it [00:52, 18.30it/s, epoch=2/500, validation_avg_epoch_loss=-5.66]
# 100%|██████████| 95/95 [00:09<00:00,  9.81it/s, epoch=3/500, avg_epoch_loss=-6.11]
# 953it [00:52, 18.06it/s, epoch=3/500, validation_avg_epoch_loss=-5.69]
# 100%|██████████| 95/95 [00:09<00:00, 10.47it/s, epoch=4/500, avg_epoch_loss=-6.03]
# 953it [00:52, 18.19it/s, epoch=4/500, validation_avg_epoch_loss=-5.73]
# 100%|██████████| 95/95 [00:09<00:00, 10.54it/s, epoch=5/500, avg_epoch_loss=-6.21]
# 953it [00:52, 18.09it/s, epoch=5/500, validation_avg_epoch_loss=-5.72]
# 100%|██████████| 95/95 [00:08<00:00, 10.64it/s, epoch=6/500, avg_epoch_loss=-7.18]
# 953it [00:52, 18.18it/s, epoch=6/500, validation_avg_epoch_loss=-5.78]
# 100%|██████████| 95/95 [00:09<00:00, 10.48it/s, epoch=7/500, avg_epoch_loss=-7.71]
# 953it [00:52, 17.99it/s, epoch=7/500, validation_avg_epoch_loss=-5.81]
# 100%|██████████| 95/95 [00:08<00:00, 10.62it/s, epoch=8/500, avg_epoch_loss=-6.83]
# 953it [00:52, 18.08it/s, epoch=8/500, validation_avg_epoch_loss=-5.92]
# 100%|██████████| 95/95 [00:09<00:00, 10.44it/s, epoch=9/500, avg_epoch_loss=-7.43]
# 953it [00:54, 17.54it/s, epoch=9/500, validation_avg_epoch_loss=-5.9]
# 100%|██████████| 95/95 [00:09<00:00, 10.26it/s, epoch=10/500, avg_epoch_loss=-7.95]
# 953it [00:53, 17.87it/s, epoch=10/500, validation_avg_epoch_loss=-5.96]
# 100%|██████████| 95/95 [00:08<00:00, 10.63it/s, epoch=11/500, avg_epoch_loss=-6.92]
# 953it [00:52, 18.18it/s, epoch=11/500, validation_avg_epoch_loss=-6.01]
# 100%|██████████| 95/95 [00:08<00:00, 10.63it/s, epoch=12/500, avg_epoch_loss=-7.07]
# 953it [00:52, 18.15it/s, epoch=12/500, validation_avg_epoch_loss=-5.99]
# 100%|██████████| 95/95 [00:09<00:00, 10.53it/s, epoch=13/500, avg_epoch_loss=-6.35]
# 953it [00:52, 18.26it/s, epoch=13/500, validation_avg_epoch_loss=-6.01]
# 100%|██████████| 95/95 [00:09<00:00, 10.36it/s, epoch=14/500, avg_epoch_loss=-6.44]
# 953it [00:52, 18.19it/s, epoch=14/500, validation_avg_epoch_loss=-6.03]
# 100%|██████████| 95/95 [00:09<00:00, 10.55it/s, epoch=15/500, avg_epoch_loss=-6.28]
# 953it [00:52, 18.13it/s, epoch=15/500, validation_avg_epoch_loss=-6.03]
# 100%|██████████| 95/95 [00:08<00:00, 10.60it/s, epoch=16/500, avg_epoch_loss=-7.57]
# 953it [00:52, 18.04it/s, epoch=16/500, validation_avg_epoch_loss=-6.07]
# 100%|██████████| 95/95 [00:08<00:00, 10.56it/s, epoch=17/500, avg_epoch_loss=-8.34]
# 953it [00:52, 18.02it/s, epoch=17/500, validation_avg_epoch_loss=-6.07]
# 100%|██████████| 95/95 [00:09<00:00, 10.49it/s, epoch=18/500, avg_epoch_loss=-7.14]
# 953it [00:52, 18.20it/s, epoch=18/500, validation_avg_epoch_loss=-6.16]
# 100%|██████████| 95/95 [00:08<00:00, 10.57it/s, epoch=19/500, avg_epoch_loss=-7.96]
# 953it [00:52, 18.02it/s, epoch=19/500, validation_avg_epoch_loss=-6.17]
# 100%|██████████| 95/95 [00:09<00:00, 10.52it/s, epoch=20/500, avg_epoch_loss=-8.54]
# 953it [00:52, 18.12it/s, epoch=20/500, validation_avg_epoch_loss=-6.2]
# 100%|██████████| 95/95 [00:09<00:00, 10.53it/s, epoch=21/500, avg_epoch_loss=-7.18]
# 953it [00:52, 18.16it/s, epoch=21/500, validation_avg_epoch_loss=-6.23]
# 100%|██████████| 95/95 [00:08<00:00, 10.61it/s, epoch=22/500, avg_epoch_loss=-7.37]
# 953it [00:53, 17.84it/s, epoch=22/500, validation_avg_epoch_loss=-6.19]
# 100%|██████████| 95/95 [00:08<00:00, 10.62it/s, epoch=23/500, avg_epoch_loss=-6.51]
# 953it [00:52, 18.25it/s, epoch=23/500, validation_avg_epoch_loss=-6.15]
# 100%|██████████| 95/95 [00:08<00:00, 10.58it/s, epoch=24/500, avg_epoch_loss=-6.56]
# 953it [00:52, 18.23it/s, epoch=24/500, validation_avg_epoch_loss=-6.24]
# 100%|██████████| 95/95 [00:08<00:00, 10.66it/s, epoch=25/500, avg_epoch_loss=-6.71]
# 953it [00:53, 17.94it/s, epoch=25/500, validation_avg_epoch_loss=-6.24]
# 100%|██████████| 95/95 [00:08<00:00, 10.67it/s, epoch=26/500, avg_epoch_loss=-7.62]
# 953it [00:52, 18.12it/s, epoch=26/500, validation_avg_epoch_loss=-6.3]
# 100%|██████████| 95/95 [00:08<00:00, 10.57it/s, epoch=27/500, avg_epoch_loss=-8.52]
# 953it [00:52, 18.15it/s, epoch=27/500, validation_avg_epoch_loss=-6.21]
# 100%|██████████| 95/95 [00:09<00:00, 10.49it/s, epoch=28/500, avg_epoch_loss=-7]
# 953it [00:53, 17.96it/s, epoch=28/500, validation_avg_epoch_loss=-6.32]
# 100%|██████████| 95/95 [00:09<00:00, 10.34it/s, epoch=29/500, avg_epoch_loss=-8.17]
# 953it [00:52, 18.10it/s, epoch=29/500, validation_avg_epoch_loss=-6.2]
# 100%|██████████| 95/95 [00:08<00:00, 10.66it/s, epoch=30/500, avg_epoch_loss=-8.6]
# 953it [00:52, 18.09it/s, epoch=30/500, validation_avg_epoch_loss=-6.2]
# 100%|██████████| 95/95 [00:08<00:00, 10.61it/s, epoch=31/500, avg_epoch_loss=-7.19]
# 953it [00:52, 18.16it/s, epoch=31/500, validation_avg_epoch_loss=-6.31]
# 100%|██████████| 95/95 [00:09<00:00, 10.47it/s, epoch=32/500, avg_epoch_loss=-7.65]
# 953it [00:52, 18.21it/s, epoch=32/500, validation_avg_epoch_loss=-6.38]
# 100%|██████████| 95/95 [00:08<00:00, 10.61it/s, epoch=33/500, avg_epoch_loss=-6.8]
# 953it [00:52, 18.18it/s, epoch=33/500, validation_avg_epoch_loss=-6.21]
# 100%|██████████| 95/95 [00:09<00:00, 10.38it/s, epoch=34/500, avg_epoch_loss=-6.71]
# 953it [00:52, 18.11it/s, epoch=34/500, validation_avg_epoch_loss=-6.14]
# 100%|██████████| 95/95 [00:09<00:00, 10.55it/s, epoch=35/500, avg_epoch_loss=-6.77]
# 953it [00:52, 18.17it/s, epoch=35/500, validation_avg_epoch_loss=-6.31]
# 100%|██████████| 95/95 [00:09<00:00, 10.44it/s, epoch=36/500, avg_epoch_loss=-8.05]
# 953it [00:52, 18.19it/s, epoch=36/500, validation_avg_epoch_loss=-6.32]
# 100%|██████████| 95/95 [00:09<00:00, 10.40it/s, epoch=37/500, avg_epoch_loss=-8.66]
# 953it [00:53, 17.95it/s, epoch=37/500, validation_avg_epoch_loss=-6.39]
# 100%|██████████| 95/95 [00:09<00:00,  9.94it/s, epoch=38/500, avg_epoch_loss=-7.3]
# 953it [00:52, 18.02it/s, epoch=38/500, validation_avg_epoch_loss=-6.39]
# 100%|██████████| 95/95 [00:09<00:00, 10.33it/s, epoch=39/500, avg_epoch_loss=-8.44]
# 953it [00:52, 17.99it/s, epoch=39/500, validation_avg_epoch_loss=-6.15]
# 100%|██████████| 95/95 [00:09<00:00, 10.53it/s, epoch=40/500, avg_epoch_loss=-8.52]
# 953it [00:52, 18.03it/s, epoch=40/500, validation_avg_epoch_loss=-6.26]
# 100%|██████████| 95/95 [00:09<00:00, 10.26it/s, epoch=41/500, avg_epoch_loss=-7.2]
# 953it [00:53, 17.96it/s, epoch=41/500, validation_avg_epoch_loss=-6.44]
# 100%|██████████| 95/95 [00:09<00:00, 10.40it/s, epoch=42/500, avg_epoch_loss=-7.6]
# 953it [00:53, 17.85it/s, epoch=42/500, validation_avg_epoch_loss=-6.4]
# 100%|██████████| 95/95 [00:09<00:00, 10.45it/s, epoch=43/500, avg_epoch_loss=-7.01]
# 953it [00:53, 17.77it/s, epoch=43/500, validation_avg_epoch_loss=-6.4]
# 100%|██████████| 95/95 [00:09<00:00, 10.50it/s, epoch=44/500, avg_epoch_loss=-6.72]
# 953it [00:53, 17.91it/s, epoch=44/500, validation_avg_epoch_loss=-6.38]
# 100%|██████████| 95/95 [00:08<00:00, 10.60it/s, epoch=45/500, avg_epoch_loss=-7.02]
# 953it [00:52, 18.03it/s, epoch=45/500, validation_avg_epoch_loss=-6.41]
# 100%|██████████| 95/95 [00:09<00:00, 10.49it/s, epoch=46/500, avg_epoch_loss=-8.03]
# 953it [00:53, 17.93it/s, epoch=46/500, validation_avg_epoch_loss=-6.39]
# 100%|██████████| 95/95 [00:09<00:00, 10.51it/s, epoch=47/500, avg_epoch_loss=-8.92]
# 953it [00:52, 18.00it/s, epoch=47/500, validation_avg_epoch_loss=-6.43]
# 100%|██████████| 95/95 [00:09<00:00, 10.55it/s, epoch=48/500, avg_epoch_loss=-7.3]
# 953it [00:52, 18.13it/s, epoch=48/500, validation_avg_epoch_loss=-6.41]
# 100%|██████████| 95/95 [00:09<00:00, 10.52it/s, epoch=49/500, avg_epoch_loss=-8.41]
# 953it [00:53, 17.88it/s, epoch=49/500, validation_avg_epoch_loss=-6.45]
# 100%|██████████| 95/95 [00:09<00:00, 10.50it/s, epoch=50/500, avg_epoch_loss=-8.87]
# 953it [00:53, 17.80it/s, epoch=50/500, validation_avg_epoch_loss=-6.24]
# 100%|██████████| 95/95 [00:09<00:00, 10.46it/s, epoch=51/500, avg_epoch_loss=-7.57]
# 953it [00:54, 17.36it/s, epoch=51/500, validation_avg_epoch_loss=-6.32]
# 100%|██████████| 95/95 [00:09<00:00, 10.47it/s, epoch=52/500, avg_epoch_loss=-7.74]
# 953it [00:53, 17.81it/s, epoch=52/500, validation_avg_epoch_loss=-6.5]
# 100%|██████████| 95/95 [00:09<00:00, 10.42it/s, epoch=53/500, avg_epoch_loss=-7.24]
# 953it [00:53, 17.84it/s, epoch=53/500, validation_avg_epoch_loss=-6.52]
# 100%|██████████| 95/95 [00:09<00:00, 10.30it/s, epoch=54/500, avg_epoch_loss=-6.8]
# 953it [00:53, 17.82it/s, epoch=54/500, validation_avg_epoch_loss=-6.44]
# 100%|██████████| 95/95 [00:09<00:00, 10.32it/s, epoch=55/500, avg_epoch_loss=-6.98]
# 953it [00:53, 17.84it/s, epoch=55/500, validation_avg_epoch_loss=-6.45]
# 100%|██████████| 95/95 [00:09<00:00, 10.48it/s, epoch=56/500, avg_epoch_loss=-8.29]
# 953it [00:53, 17.78it/s, epoch=56/500, validation_avg_epoch_loss=-6.53]
# 100%|██████████| 95/95 [00:09<00:00, 10.42it/s, epoch=57/500, avg_epoch_loss=-9]
# 953it [00:54, 17.60it/s, epoch=57/500, validation_avg_epoch_loss=-6.53]
# 100%|██████████| 95/95 [00:09<00:00, 10.46it/s, epoch=58/500, avg_epoch_loss=-7.26]
# 953it [00:53, 17.92it/s, epoch=58/500, validation_avg_epoch_loss=-6.31]
# 100%|██████████| 95/95 [00:09<00:00, 10.39it/s, epoch=59/500, avg_epoch_loss=-8.32]
# 953it [00:52, 18.01it/s, epoch=59/500, validation_avg_epoch_loss=-6.54]
# 100%|██████████| 95/95 [00:09<00:00, 10.47it/s, epoch=60/500, avg_epoch_loss=-9.03]
# 953it [00:53, 17.97it/s, epoch=60/500, validation_avg_epoch_loss=-6.24]
# 100%|██████████| 95/95 [00:09<00:00, 10.40it/s, epoch=61/500, avg_epoch_loss=-7.62]
# 953it [00:52, 18.16it/s, epoch=61/500, validation_avg_epoch_loss=-6.32]
# 100%|██████████| 95/95 [00:09<00:00, 10.42it/s, epoch=62/500, avg_epoch_loss=-7.88]
# 953it [00:53, 17.75it/s, epoch=62/500, validation_avg_epoch_loss=-6.53]
# 100%|██████████| 95/95 [00:09<00:00, 10.43it/s, epoch=63/500, avg_epoch_loss=-7.11]
# 953it [00:53, 17.96it/s, epoch=63/500, validation_avg_epoch_loss=-6.54]
# 100%|██████████| 95/95 [00:09<00:00, 10.47it/s, epoch=64/500, avg_epoch_loss=-7.02]
# 953it [00:53, 17.93it/s, epoch=64/500, validation_avg_epoch_loss=-6.27]
# 100%|██████████| 95/95 [00:09<00:00, 10.48it/s, epoch=65/500, avg_epoch_loss=-7.15]
# 953it [00:53, 17.97it/s, epoch=65/500, validation_avg_epoch_loss=-6.57]
# 100%|██████████| 95/95 [00:09<00:00, 10.46it/s, epoch=66/500, avg_epoch_loss=-8.38]
# 953it [00:53, 17.84it/s, epoch=66/500, validation_avg_epoch_loss=-6.59]
# 100%|██████████| 95/95 [00:09<00:00, 10.45it/s, epoch=67/500, avg_epoch_loss=-9.03]
# 953it [00:53, 17.88it/s, epoch=67/500, validation_avg_epoch_loss=-6.54]
# 100%|██████████| 95/95 [00:09<00:00, 10.46it/s, epoch=68/500, avg_epoch_loss=-7.51]
# 953it [00:53, 17.92it/s, epoch=68/500, validation_avg_epoch_loss=-6.16]
# 100%|██████████| 95/95 [00:09<00:00, 10.39it/s, epoch=69/500, avg_epoch_loss=-8.22]
# 953it [00:53, 17.89it/s, epoch=69/500, validation_avg_epoch_loss=-6.57]
# 100%|██████████| 95/95 [00:09<00:00, 10.53it/s, epoch=70/500, avg_epoch_loss=-9.29]
# 953it [00:53, 17.93it/s, epoch=70/500, validation_avg_epoch_loss=-6.63]
# 100%|██████████| 95/95 [00:09<00:00, 10.43it/s, epoch=71/500, avg_epoch_loss=-7.83]
# 953it [00:52, 18.10it/s, epoch=71/500, validation_avg_epoch_loss=-6.6]
# 100%|██████████| 95/95 [00:09<00:00, 10.42it/s, epoch=72/500, avg_epoch_loss=-8.14]
# 953it [00:52, 18.03it/s, epoch=72/500, validation_avg_epoch_loss=-6.67]
# 100%|██████████| 95/95 [00:09<00:00, 10.45it/s, epoch=73/500, avg_epoch_loss=-7.34]
# 953it [00:52, 18.06it/s, epoch=73/500, validation_avg_epoch_loss=-6.57]
# 100%|██████████| 95/95 [00:09<00:00, 10.42it/s, epoch=74/500, avg_epoch_loss=-7.08]
# 953it [00:53, 17.82it/s, epoch=74/500, validation_avg_epoch_loss=-6.58]
# 100%|██████████| 95/95 [00:09<00:00, 10.38it/s, epoch=75/500, avg_epoch_loss=-7.26]
# 953it [00:53, 17.89it/s, epoch=75/500, validation_avg_epoch_loss=-6.67]
# 100%|██████████| 95/95 [00:09<00:00, 10.42it/s, epoch=76/500, avg_epoch_loss=-8.39]
# 953it [00:53, 17.91it/s, epoch=76/500, validation_avg_epoch_loss=-6.45]
# 100%|██████████| 95/95 [00:09<00:00, 10.51it/s, epoch=77/500, avg_epoch_loss=-9.28]
# 953it [00:52, 18.01it/s, epoch=77/500, validation_avg_epoch_loss=-6.37]
# 100%|██████████| 95/95 [00:09<00:00, 10.36it/s, epoch=78/500, avg_epoch_loss=-7.57]
# 953it [00:53, 17.91it/s, epoch=78/500, validation_avg_epoch_loss=-6.71]
# 100%|██████████| 95/95 [00:09<00:00, 10.42it/s, epoch=79/500, avg_epoch_loss=-8.46]
# 953it [00:52, 18.10it/s, epoch=79/500, validation_avg_epoch_loss=-6.67]
# 100%|██████████| 95/95 [00:09<00:00, 10.51it/s, epoch=80/500, avg_epoch_loss=-9.39]
# 953it [00:53, 17.86it/s, epoch=80/500, validation_avg_epoch_loss=-6.8]
# 100%|██████████| 95/95 [00:09<00:00, 10.32it/s, epoch=81/500, avg_epoch_loss=-8.01]
# 953it [00:53, 17.92it/s, epoch=81/500, validation_avg_epoch_loss=-6.69]
# 100%|██████████| 95/95 [00:09<00:00, 10.29it/s, epoch=82/500, avg_epoch_loss=-8.2]
# 953it [00:52, 18.08it/s, epoch=82/500, validation_avg_epoch_loss=-6.52]
# 100%|██████████| 95/95 [00:08<00:00, 10.65it/s, epoch=83/500, avg_epoch_loss=-7.29]
# 953it [00:52, 18.00it/s, epoch=83/500, validation_avg_epoch_loss=-6.57]
# 100%|██████████| 95/95 [00:09<00:00, 10.51it/s, epoch=84/500, avg_epoch_loss=-7.16]
# 953it [00:53, 17.93it/s, epoch=84/500, validation_avg_epoch_loss=-6.76]
# 100%|██████████| 95/95 [00:09<00:00, 10.39it/s, epoch=85/500, avg_epoch_loss=-7.34]
# 953it [00:53, 17.77it/s, epoch=85/500, validation_avg_epoch_loss=-6.78]
# 100%|██████████| 95/95 [00:08<00:00, 10.56it/s, epoch=86/500, avg_epoch_loss=-8.5]
# 953it [00:53, 17.79it/s, epoch=86/500, validation_avg_epoch_loss=-6.7]
# 100%|██████████| 95/95 [00:09<00:00, 10.52it/s, epoch=87/500, avg_epoch_loss=-9.41]
# 953it [00:53, 17.75it/s, epoch=87/500, validation_avg_epoch_loss=-6.72]
# 100%|██████████| 95/95 [00:09<00:00, 10.21it/s, epoch=88/500, avg_epoch_loss=-7.66]
# 953it [00:53, 17.85it/s, epoch=88/500, validation_avg_epoch_loss=-6.76]
# 100%|██████████| 95/95 [00:09<00:00, 10.38it/s, epoch=89/500, avg_epoch_loss=-8.56]
# 953it [00:53, 17.94it/s, epoch=89/500, validation_avg_epoch_loss=-6.84]
# 100%|██████████| 95/95 [00:08<00:00, 10.60it/s, epoch=90/500, avg_epoch_loss=-9.34]
# 953it [00:53, 17.98it/s, epoch=90/500, validation_avg_epoch_loss=-6.72]
# 100%|██████████| 95/95 [00:09<00:00, 10.46it/s, epoch=91/500, avg_epoch_loss=-8.17]
# 953it [00:53, 17.95it/s, epoch=91/500, validation_avg_epoch_loss=-6.98]
# 100%|██████████| 95/95 [00:09<00:00, 10.26it/s, epoch=92/500, avg_epoch_loss=-8.29]
# 953it [00:53, 17.89it/s, epoch=92/500, validation_avg_epoch_loss=-6.93]
# 100%|██████████| 95/95 [00:09<00:00, 10.46it/s, epoch=93/500, avg_epoch_loss=-7.55]
# 953it [00:52, 18.01it/s, epoch=93/500, validation_avg_epoch_loss=-6.98]
# 100%|██████████| 95/95 [00:09<00:00, 10.51it/s, epoch=94/500, avg_epoch_loss=-7.49]
# 953it [00:53, 17.92it/s, epoch=94/500, validation_avg_epoch_loss=-6.93]
# 100%|██████████| 95/95 [00:09<00:00, 10.47it/s, epoch=95/500, avg_epoch_loss=-7.48]
# 953it [00:53, 17.72it/s, epoch=95/500, validation_avg_epoch_loss=-7.1]
# 100%|██████████| 95/95 [00:09<00:00, 10.40it/s, epoch=96/500, avg_epoch_loss=-8.76]
# 953it [00:53, 17.88it/s, epoch=96/500, validation_avg_epoch_loss=-7.14]
# 100%|██████████| 95/95 [00:09<00:00, 10.52it/s, epoch=97/500, avg_epoch_loss=-9.53]
# 953it [00:53, 17.93it/s, epoch=97/500, validation_avg_epoch_loss=-7.1]
# 100%|██████████| 95/95 [00:09<00:00, 10.43it/s, epoch=98/500, avg_epoch_loss=-8.14]
# 953it [00:53, 17.89it/s, epoch=98/500, validation_avg_epoch_loss=-7.26]
# 100%|██████████| 95/95 [00:08<00:00, 10.58it/s, epoch=99/500, avg_epoch_loss=-8.83]
# 953it [00:53, 17.92it/s, epoch=99/500, validation_avg_epoch_loss=-7.21]
# 100%|██████████| 95/95 [00:09<00:00, 10.44it/s, epoch=100/500, avg_epoch_loss=-9.67]
# 953it [00:53, 17.91it/s, epoch=100/500, validation_avg_epoch_loss=-7.24]
# 100%|██████████| 95/95 [00:09<00:00, 10.50it/s, epoch=101/500, avg_epoch_loss=-8.55]
# 953it [00:52, 18.13it/s, epoch=101/500, validation_avg_epoch_loss=-7.28]
# 100%|██████████| 95/95 [00:09<00:00, 10.49it/s, epoch=102/500, avg_epoch_loss=-8.51]
# 953it [00:52, 18.03it/s, epoch=102/500, validation_avg_epoch_loss=-7.39]
# 100%|██████████| 95/95 [00:08<00:00, 10.62it/s, epoch=103/500, avg_epoch_loss=-8.06]
# 953it [00:53, 17.84it/s, epoch=103/500, validation_avg_epoch_loss=-7.14]
# 100%|██████████| 95/95 [00:09<00:00, 10.41it/s, epoch=104/500, avg_epoch_loss=-7.7]
# 953it [00:53, 17.94it/s, epoch=104/500, validation_avg_epoch_loss=-7.5]
# 100%|██████████| 95/95 [00:09<00:00, 10.42it/s, epoch=105/500, avg_epoch_loss=-7.87]
# 953it [00:53, 17.86it/s, epoch=105/500, validation_avg_epoch_loss=-7.32]
# 100%|██████████| 95/95 [00:09<00:00, 10.49it/s, epoch=106/500, avg_epoch_loss=-9.14]
# 953it [00:53, 17.91it/s, epoch=106/500, validation_avg_epoch_loss=-7.61]
# 100%|██████████| 95/95 [00:09<00:00, 10.53it/s, epoch=107/500, avg_epoch_loss=-9.92]
# 953it [00:53, 17.96it/s, epoch=107/500, validation_avg_epoch_loss=-7.69]
# 100%|██████████| 95/95 [00:09<00:00, 10.45it/s, epoch=108/500, avg_epoch_loss=-8.39]
# 953it [00:53, 17.91it/s, epoch=108/500, validation_avg_epoch_loss=-7.77]
# 100%|██████████| 95/95 [00:09<00:00, 10.45it/s, epoch=109/500, avg_epoch_loss=-9.17]
# 953it [00:53, 17.77it/s, epoch=109/500, validation_avg_epoch_loss=-7.31]
# 100%|██████████| 95/95 [00:09<00:00, 10.47it/s, epoch=110/500, avg_epoch_loss=-10.2]
# 953it [00:53, 17.95it/s, epoch=110/500, validation_avg_epoch_loss=-7.54]
# 100%|██████████| 95/95 [00:08<00:00, 10.57it/s, epoch=111/500, avg_epoch_loss=-8.8]
# 953it [00:52, 18.00it/s, epoch=111/500, validation_avg_epoch_loss=-7.9]
# 100%|██████████| 95/95 [00:09<00:00, 10.49it/s, epoch=112/500, avg_epoch_loss=-8.9]
# 953it [00:52, 18.20it/s, epoch=112/500, validation_avg_epoch_loss=-7.79]
# 100%|██████████| 95/95 [00:08<00:00, 10.57it/s, epoch=113/500, avg_epoch_loss=-8.28]
# 953it [00:53, 17.97it/s, epoch=113/500, validation_avg_epoch_loss=-7.79]
# 100%|██████████| 95/95 [00:09<00:00,  9.51it/s, epoch=114/500, avg_epoch_loss=-7.86]
# 953it [00:53, 17.68it/s, epoch=114/500, validation_avg_epoch_loss=-7.9]
# 100%|██████████| 95/95 [00:09<00:00, 10.44it/s, epoch=115/500, avg_epoch_loss=-8.01]
# 953it [00:53, 17.94it/s, epoch=115/500, validation_avg_epoch_loss=-7.85]
# 100%|██████████| 95/95 [00:08<00:00, 10.57it/s, epoch=116/500, avg_epoch_loss=-9.4]
# 953it [00:53, 17.93it/s, epoch=116/500, validation_avg_epoch_loss=-7.5]
# 100%|██████████| 95/95 [00:09<00:00, 10.39it/s, epoch=117/500, avg_epoch_loss=-10.1]
# 953it [00:52, 17.99it/s, epoch=117/500, validation_avg_epoch_loss=-7.96]
# 100%|██████████| 95/95 [00:09<00:00, 10.40it/s, epoch=118/500, avg_epoch_loss=-8.75]
# 953it [00:53, 17.75it/s, epoch=118/500, validation_avg_epoch_loss=-7.87]
# 100%|██████████| 95/95 [00:09<00:00, 10.52it/s, epoch=119/500, avg_epoch_loss=-9.46]
# 953it [00:53, 17.86it/s, epoch=119/500, validation_avg_epoch_loss=-7.96]
# 100%|██████████| 95/95 [00:09<00:00, 10.33it/s, epoch=120/500, avg_epoch_loss=-10.5]
# 953it [00:53, 17.76it/s, epoch=120/500, validation_avg_epoch_loss=-8.27]
# 100%|██████████| 95/95 [00:08<00:00, 10.56it/s, epoch=121/500, avg_epoch_loss=-9.05]
# 953it [00:52, 18.04it/s, epoch=121/500, validation_avg_epoch_loss=-7.97]
# 100%|██████████| 95/95 [00:09<00:00, 10.42it/s, epoch=122/500, avg_epoch_loss=-9.12]
# 953it [00:53, 17.93it/s, epoch=122/500, validation_avg_epoch_loss=-8.03]
# 100%|██████████| 95/95 [00:09<00:00, 10.48it/s, epoch=123/500, avg_epoch_loss=-8.56]
# 953it [00:53, 17.91it/s, epoch=123/500, validation_avg_epoch_loss=-8.26]
# 100%|██████████| 95/95 [00:08<00:00, 10.57it/s, epoch=124/500, avg_epoch_loss=-8.31]
# 953it [00:53, 17.85it/s, epoch=124/500, validation_avg_epoch_loss=-7.93]
# 100%|██████████| 95/95 [00:09<00:00, 10.48it/s, epoch=125/500, avg_epoch_loss=-8.28]
# 953it [00:53, 17.91it/s, epoch=125/500, validation_avg_epoch_loss=-8.3]
# 100%|██████████| 95/95 [00:09<00:00, 10.46it/s, epoch=126/500, avg_epoch_loss=-9.53]
# 953it [00:52, 18.07it/s, epoch=126/500, validation_avg_epoch_loss=-8.4]
# 100%|██████████| 95/95 [00:09<00:00, 10.52it/s, epoch=127/500, avg_epoch_loss=-10.6]
# 953it [00:53, 17.93it/s, epoch=127/500, validation_avg_epoch_loss=-8.09]
# 100%|██████████| 95/95 [00:09<00:00, 10.36it/s, epoch=128/500, avg_epoch_loss=-8.92]
# 953it [00:53, 17.98it/s, epoch=128/500, validation_avg_epoch_loss=-8.24]
# 100%|██████████| 95/95 [00:09<00:00, 10.49it/s, epoch=129/500, avg_epoch_loss=-9.18]
# 953it [00:53, 17.84it/s, epoch=129/500, validation_avg_epoch_loss=-8.15]
# 100%|██████████| 95/95 [00:09<00:00, 10.36it/s, epoch=130/500, avg_epoch_loss=-10.8]
# 953it [00:52, 18.00it/s, epoch=130/500, validation_avg_epoch_loss=-8.47]
# 100%|██████████| 95/95 [00:09<00:00, 10.45it/s, epoch=131/500, avg_epoch_loss=-9.5]
# 953it [00:53, 17.87it/s, epoch=131/500, validation_avg_epoch_loss=-8.18]
# 100%|██████████| 95/95 [00:09<00:00, 10.41it/s, epoch=132/500, avg_epoch_loss=-9.32]
# 953it [00:53, 17.85it/s, epoch=132/500, validation_avg_epoch_loss=-8.18]
# 100%|██████████| 95/95 [00:09<00:00, 10.46it/s, epoch=133/500, avg_epoch_loss=-8.79]
# 953it [00:53, 17.85it/s, epoch=133/500, validation_avg_epoch_loss=-8.32]
# 100%|██████████| 95/95 [00:09<00:00, 10.43it/s, epoch=134/500, avg_epoch_loss=-8.23]
# 953it [00:53, 17.88it/s, epoch=134/500, validation_avg_epoch_loss=-8.06]
# 100%|██████████| 95/95 [00:09<00:00, 10.44it/s, epoch=135/500, avg_epoch_loss=-8.32]
# 953it [00:53, 17.94it/s, epoch=135/500, validation_avg_epoch_loss=-8.35]
# 100%|██████████| 95/95 [00:09<00:00, 10.38it/s, epoch=136/500, avg_epoch_loss=-9.45]
# 953it [00:52, 18.05it/s, epoch=136/500, validation_avg_epoch_loss=-8.28]
# 100%|██████████| 95/95 [00:09<00:00, 10.46it/s, epoch=137/500, avg_epoch_loss=-10.6]
# 953it [00:53, 17.91it/s, epoch=137/500, validation_avg_epoch_loss=-8]
# 100%|██████████| 95/95 [00:09<00:00, 10.27it/s, epoch=138/500, avg_epoch_loss=-9.09]
# 953it [00:52, 17.99it/s, epoch=138/500, validation_avg_epoch_loss=-7.83]
# 100%|██████████| 95/95 [00:09<00:00, 10.38it/s, epoch=139/500, avg_epoch_loss=-9.13]
# 953it [00:52, 17.99it/s, epoch=139/500, validation_avg_epoch_loss=-8.4]
# 100%|██████████| 95/95 [00:09<00:00, 10.45it/s, epoch=140/500, avg_epoch_loss=-10.9]
# 953it [00:53, 17.86it/s, epoch=140/500, validation_avg_epoch_loss=-8.49]
# 100%|██████████| 95/95 [00:09<00:00, 10.45it/s, epoch=141/500, avg_epoch_loss=-9.66]
# 953it [00:52, 18.06it/s, epoch=141/500, validation_avg_epoch_loss=-8.45]
# 100%|██████████| 95/95 [00:08<00:00, 10.59it/s, epoch=142/500, avg_epoch_loss=-9.31]
# 953it [00:53, 17.91it/s, epoch=142/500, validation_avg_epoch_loss=-8]
# 100%|██████████| 95/95 [00:09<00:00, 10.40it/s, epoch=143/500, avg_epoch_loss=-8.86]
# 953it [00:53, 17.80it/s, epoch=143/500, validation_avg_epoch_loss=-8.53]
# 100%|██████████| 95/95 [00:09<00:00, 10.47it/s, epoch=144/500, avg_epoch_loss=-8.42]
# 953it [00:53, 17.82it/s, epoch=144/500, validation_avg_epoch_loss=-8.46]
# 100%|██████████| 95/95 [00:09<00:00, 10.53it/s, epoch=145/500, avg_epoch_loss=-8.36]
# 953it [00:53, 17.85it/s, epoch=145/500, validation_avg_epoch_loss=-8.55]
# 100%|██████████| 95/95 [00:09<00:00, 10.44it/s, epoch=146/500, avg_epoch_loss=-9.66]
# 953it [00:53, 17.92it/s, epoch=146/500, validation_avg_epoch_loss=-8.5]
# 100%|██████████| 95/95 [00:09<00:00, 10.47it/s, epoch=147/500, avg_epoch_loss=-10.9]
# 953it [00:52, 17.99it/s, epoch=147/500, validation_avg_epoch_loss=-8.68]
# 100%|██████████| 95/95 [00:09<00:00, 10.40it/s, epoch=148/500, avg_epoch_loss=-9.31]
# 953it [00:53, 17.89it/s, epoch=148/500, validation_avg_epoch_loss=-8.81]
# 100%|██████████| 95/95 [00:09<00:00, 10.36it/s, epoch=149/500, avg_epoch_loss=-9.57]
# 953it [00:53, 17.76it/s, epoch=149/500, validation_avg_epoch_loss=-8.31]
# 100%|██████████| 95/95 [00:09<00:00, 10.25it/s, epoch=150/500, avg_epoch_loss=-10.8]
# 953it [00:53, 17.87it/s, epoch=150/500, validation_avg_epoch_loss=-8.37]
# 100%|██████████| 95/95 [00:09<00:00, 10.42it/s, epoch=151/500, avg_epoch_loss=-9.81]
# 953it [00:53, 17.80it/s, epoch=151/500, validation_avg_epoch_loss=-8.61]
# 100%|██████████| 95/95 [00:09<00:00, 10.54it/s, epoch=152/500, avg_epoch_loss=-9.22]
# 953it [00:53, 17.92it/s, epoch=152/500, validation_avg_epoch_loss=-8.48]
# 100%|██████████| 95/95 [00:09<00:00, 10.42it/s, epoch=153/500, avg_epoch_loss=-8.79]
# 953it [00:53, 17.82it/s, epoch=153/500, validation_avg_epoch_loss=-8.56]
# 100%|██████████| 95/95 [00:09<00:00, 10.38it/s, epoch=154/500, avg_epoch_loss=-8.62]
# 953it [00:53, 17.86it/s, epoch=154/500, validation_avg_epoch_loss=-8.65]
# 100%|██████████| 95/95 [00:09<00:00, 10.37it/s, epoch=155/500, avg_epoch_loss=-8.61]
# 953it [00:53, 17.95it/s, epoch=155/500, validation_avg_epoch_loss=-8.66]
# 100%|██████████| 95/95 [00:09<00:00, 10.48it/s, epoch=156/500, avg_epoch_loss=-9.77]
# 953it [00:53, 17.93it/s, epoch=156/500, validation_avg_epoch_loss=-8.53]
# 100%|██████████| 95/95 [00:09<00:00, 10.52it/s, epoch=157/500, avg_epoch_loss=-10.9]
# 953it [00:52, 17.99it/s, epoch=157/500, validation_avg_epoch_loss=-8.47]
# 100%|██████████| 95/95 [00:09<00:00, 10.32it/s, epoch=158/500, avg_epoch_loss=-9.22]
# 953it [00:53, 17.89it/s, epoch=158/500, validation_avg_epoch_loss=-8.79]
# Early stopping triggered
# Restored best estimator
# WARNING:root:Serializing RepresentableBlockPredictor instances does not save the prediction network structure in a backwards-compatible manner. Be careful not to use this method in production.
# End training... 163.8 minutes
# Start predicting...
# End predicting... 27.6 minutes
# Start saving...
# End saving... 0.4 minutes
# Start plotting...

# %%
epochs=1
learning_rate=1e-3
level_idx=1

save_dir = f'../result/learning_rate_{learning_rate}'
os.makedirs(save_dir, exist_ok=True)

# level directory
level_dir = os.path.join(save_dir, f'level_{level_idx}')
os.makedirs(level_dir, exist_ok=True)

highlight_print(f"\n========== Level {level_idx} ==========")
print(f"Loading dataset...", end=' ')
dataset_start = time.time()
with open(os.path.join('../dataset', f'dataset_level_{level_idx}.pkl'), 'rb') as f:
    dataset = pickle.load(f)
print(f"{(time.time() - dataset_start)/60:.1f} minutes")

print("Normalizing dataset...", end=' ')
normalize_start = time.time()
norm_train_dataset, norm_test_dataset, normalizer = normalize_dataset(
    dataset['train'], 
    dataset['test'],
)
with open(os.path.join(level_dir, 'normalizer.pkl'), 'wb') as f:
    pickle.dump(normalizer, f)
print(f"{(time.time() - normalize_start)/60:.1f} minutes")

estimators = create_estimators(
    level_idx=level_idx, 
    train_dataset=norm_train_dataset
)
for estimator_name, estimator in estimators.items():
    # estimator directory
    estimator_dir = os.path.join(level_dir, estimator_name)
    os.makedirs(estimator_dir, exist_ok=True)

    estimator_start = time.time()

    highlight_print(f"\n---------- {estimator_name} ----------")
    print("Start training...")
    train_start = time.time()
    estimator.trainer = EarlyStoppingTrainer(
        epochs=epochs,
        learning_rate=learning_rate,
        num_batches_per_epoch=get_optimal_num_batches(mx.context.num_gpus()),
    )
    predictor = estimator.train(
        training_data=norm_train_dataset,
        validation_data=norm_test_dataset
    )
    predictor.serialize(Path(f"{level_dir}/{estimator_name}"))
    highlight_print(f"End training... {(time.time() - train_start)/60:.1f} minutes", color='green')

    print("Start predicting...")
    pred_start = time.time()
    train_forecasts_it, train_labels_it = make_evaluation_predictions(
        dataset=norm_train_dataset,
        predictor=predictor,
    )
    train_forecasts = list(train_forecasts_it)
    train_labels = list(train_labels_it)

    test_forecasts_it, test_labels_it = make_evaluation_predictions(
        dataset=norm_test_dataset,
        predictor=predictor,
    )
    test_forecasts = list(test_forecasts_it)
    test_labels = list(test_labels_it)
    highlight_print(f"End predicting... {(time.time() - pred_start)/60:.1f} minutes", color='green')

    print("Start saving...")
    pred_save_start = time.time()
    for i in range(len(train_forecasts)):
        train_forecasts[i] = normalizer.inverse_transform_forecast(train_forecasts[i])
    for i in range(len(test_forecasts)):
        test_forecasts[i] = normalizer.inverse_transform_forecast(test_forecasts[i])
    for i in range(len(train_labels)):
        train_labels[i] = normalizer.inverse_transform_labels(train_labels[i])
    for i in range(len(test_labels)):
        test_labels[i] = normalizer.inverse_transform_labels(test_labels[i])
    with open(f"{level_dir}/{estimator_name}/train_labels.pkl", "wb") as f:
        pickle.dump(train_labels, f)
    with open(f"{level_dir}/{estimator_name}/train_forecasts.pkl", "wb") as f:
        pickle.dump(train_forecasts, f)
    with open(f"{level_dir}/{estimator_name}/test_labels.pkl", "wb") as f:
        pickle.dump(test_labels, f)
    with open(f"{level_dir}/{estimator_name}/test_forecasts.pkl", "wb") as f:
        pickle.dump(test_forecasts, f)
    highlight_print(f"End saving... {(time.time() - pred_save_start)/60:.1f} minutes", color='green')

    print("Start plotting...")
    plot_start = time.time()
    for i in range(len(test_forecasts)):
        plt.figure(figsize=(12, 6))
        plt.plot(test_labels[i][-100:].to_timestamp(), label="Actual")
        plt.plot(pd.Series(test_forecasts[i].quantile(0.5), index=test_forecasts[i].start_date.to_timestamp() + pd.to_timedelta(range(len(test_forecasts[0].quantile(0.5))), unit='D')), label="Forecast")
        plt.title(f'{test_forecasts[i].item_id}', color='white')
        plt.xlabel('Date', color='white')
        plt.ylabel('Sales', color='white')
        plt.xticks(color='white')
        plt.yticks(color='white')
        plt.legend(loc="upper right")
        plt.savefig(os.path.join(estimator_dir, f'series_{i + 1}.png'))
        plt.close()
    highlight_print(f"End plotting... {(time.time() - plot_start)/60:.1f} minutes", color='green')
        
    print("Start evaluating...")
    eval_start = time.time()
    evaluator = Evaluator(quantiles=(0.5,), ignore_invalid_values=True)
    train_metrics_all_id, train_metrics_per_id = evaluator(train_labels, train_forecasts)
    test_metrics_all_id, test_metrics_per_id = evaluator(test_labels, test_forecasts)
    highlight_print(f"End evaluating... {(time.time() - eval_start)/60:.1f} minutes", color='green')

    print("Start saving...")
    eval_save_start = time.time()
    with open(f"{level_dir}/{estimator_name}/train_metrics_all_id.pkl", "wb") as f:
        pickle.dump(train_metrics_all_id, f)
    with open(f"{level_dir}/{estimator_name}/train_metrics_per_id.pkl", "wb") as f:
        pickle.dump(train_metrics_per_id, f)
    with open(f"{level_dir}/{estimator_name}/test_metrics_all_id.pkl", "wb") as f:
        pickle.dump(test_metrics_all_id, f)
    with open(f"{level_dir}/{estimator_name}/test_metrics_per_id.pkl", "wb") as f:
        pickle.dump(test_metrics_per_id, f)
    highlight_print(f"End saving... {(time.time() - eval_save_start)/60:.1f} minutes", color='green')

    highlight_print(f"\nTotal time: {(time.time() - estimator_start)/60:.1f} minutes", color='red')

    # rename estimator directory
    os.rename(estimator_dir, f"{estimator_dir}_{test_metrics_all_id['MASE']:.2f}")
